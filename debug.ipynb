# %%
import argparse
from urllib.parse import urlparse, unquote
from datetime import datetime
import time 
from pyspark.sql import SparkSession
from pyspark.sql.functions import pandas_udf, approx_count_distinct, count, col, when, regexp_extract, window, lit, to_timestamp
from pyspark.sql.types import StringType, TimestampType

spark = SparkSession.builder \
.config("spark.sql.shuffle.partitions", "4")\
.master("yarn") \
.appName("spark-course") \
.config("spark.driver.memory", "1g") \
.config("spark.driver.cores", "1") \
.config("spark.executor.instances", "6") \
.config("spark.executor.cores", "3") \
.config("spark.executor.memory", "1g") \
.getOrCreate()

spark.sparkContext.setLogLevel("WARN")


@pandas_udf(StringType())
def url2domain(url):

    domain = url.apply(lambda x: urlparse(unquote(x.strip())).netloc.strip()
                     if urlparse(unquote(x.strip())).scheme in ['http','https']
                     else '')

    return domain


@pandas_udf(TimestampType())
def ts2datetime(unix_ts):

    return unix_ts.apply(lambda x: datetime.fromtimestamp(x))

# %%
page_views_raw = spark \
.read \
.format("kafka") \
.option("kafka.bootstrap.servers", 
            "brain-node1.bigdatateam.org:9092,brain-node2.bigdatateam.org:9092,brain-node3.bigdatateam.org:9092") \
.option("startingOffsets", "earliest") \
.option("subscribe", "page_views") \
.load()

page_views_raw.createOrReplaceTempView("page_views")

page_views = spark.sql("""
select
    cast(splitted[0] as long) as ts,
    cast(splitted[0] as double) as ts_2,
    splitted[1] as uid,
    splitted[2] as url,
    parse_url(splitted[2], 'HOST') as domain_m,
    splitted[3] as title,
    splitted[4] as ua,
    case when parse_url(splitted[2], 'HOST') like '%.ru' then 'ru' else 'not ru' end as zone_m
from (
    select split(cast(value as string), '\t') as splitted
    from page_views
) t
""")
page_views = page_views.withColumn("domain_0", url2domain(page_views.url)) 
page_views = page_views.withColumn("timestamp", to_timestamp(page_views.ts))


page_views = page_views.withColumn("zone_0", 
                                   when(regexp_extract(url2domain(page_views.url), r'.+\.(ru)$', 1) == "ru", "ru")
                                   .otherwise("not ru"))



#dates = ("2018-04-01 16:20:41",  "2018-04-01 16:20:43")
#
#timestamps = (
#    time.mktime(datetime.strptime(s, "%Y-%m-%d %H:%M:%S").timetuple())
#    for s in dates)
#
#q1 = "CAST(timestamp AS INT) BETWEEN {0} AND {1}".format(*timestamps)
#print(page_views.filter(col("timestamp") != col("timestamp_1")).count())

page_views\
.filter(col("zone_0") != col("zone_m"))\
.select("url", "domain_0", "domain_m", "zone_0", "zone_m")\
.show(500, vertical=True, truncate=False)

#streaming = page_views\
#.groupBy(window("timestamp", "2 seconds", "1 second"), "zone")\
#.agg(approx_count_distinct("uid").alias("unique"),
#    count("uid").alias("view"))\
#.orderBy(col("window").asc(), col("view").desc())\
#.limit(20)\
#.writeStream \
#.outputMode("complete") \
#.format("console") \
#.option("truncate", "false") \
#.trigger(processingTime='5 seconds')\
#.start()
# Out:
# -RECORD 0-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
#  url      | https://www.sportmaster.ru/product/10094944/?icid=catalog/sport/podarochnye_karty/|recent|10094944
#  domain_0 | www.sportmaster.ru
#  domain_m | null
#  zone_0   | ru
#  zone_m   | not ru
# -RECORD 1-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
#  url      | https://ipoteka.domclick.ru/?utm_source=yandex&utm_medium=cpc&utm_campaign=ipoteka_frk_mar_apr_2018_context_search_brand_msk.31171813&utm_term=%D0%BA%D0%B0%D0%BA%D0%BE%D0%B9%20%D0%BF%D1%80%D0%BE%D1%86%D0%B5%D0%BD%D1%82%20%D0%B8%D0%BF%D0%BE%D1%82%D0%B5%D0%BA%D0%B8%20%D0%B2%20%D1%81%D0%B1%D0%B5%D1%80%D0%B1%D0%B0%D0%BD%D0%BA%D0%B5&utm_id=ic|31171813|3025384769|5536684225|11489166194||search|premium&yclid=1620695119668451398
#  domain_0 | ipoteka.domclick.ru
#  domain_m | null
#  zone_0   | ru
#  zone_m   | not ru
# -RECORD 2-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
#  url      
ru
#  domain_m | null
#  zone_0   | ru
#  zone_m   | not ru
# -RECORD 9-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
#  url      | http://makita.vseinstrumenti.ru/?utm_source=yandex&utm_medium=cpc&utm_campaign=Postavshik_Makita&utm_content=2434836056&utm_term=ST:search|S:none|AP:no|PT:premium|P:1|DT:desktop|RI:213|CI:19965373|GI:1679590645|PI:6407206149|AI:2434836056|RT:|KW:%D0%BC%D0%B0%D0%BA%D0%B8%D1%82%D0%B0%20%D0%BE%D1%84%D0%B8%D1%86%D0%B8%D0%B0%D0%BB%D1%8C%D0%BD%D1%8B%D0%B9%20%D1%81%D0%B0%D0%B9%D1%82|RN:%d0%9c%d0%be%d1%81%d0%ba%d0%b2%d0%b0
#  domain_0 | makita.vseinstrumenti.ru
#  domain_m | null
#  zone_0   | ru
#  zone_m   | not ru
# -RECORD 10----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
#  url      | https://sportiv.ru/bikes/brands/ghost/?utm_source=adwords_bike&utm_medium=cpc&utm_campaign=rk_prioritetnye_brendy_rf&utm_term=%D0%B2%D0%B5%D0%BB%D0%BE%D1%81%D0%B8%D0%BF%D0%B5%D0%B4%D1%8B%20%D0%B3%D0%BE%D1%81%D1%82&cm_id={campaign_id}_{gbid}_{banner_id}_{phrase_id}&gclid=EAIaIQobChMIz57t4pSZ2gIVQoUZCh2IgAY8EAEYASAAEgLybfD_BwE
#  domain_0 | sportiv.ru
#  domain_m | null
#  zone_0   | ru
#  zone_m   | not ru
# -RECORD 11----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
#  url      | https://www.natalie-tours.ru/guide/1295/1872/6387/?cm_id=34141774_3273409420_5592078533_12884603954__m.tsargrad.tv_context_type1_no_mobile_none_54&utm_medium=cpc&utm_source=yandex&utm_campaign=04_2018_turkey_s_rus|34141774&utm_term=%D0%A2%D1%83%D1%80%D1%86%D0%B8%D1%8F%202018&utm_content=k50id|0100000012884603954_|cid|34141774|gid|3273409420|aid|5592078533|adp|no|pos|none0|src|context_m.tsargrad.tv|dvc|mobile|dop_1|region|54&k50id=0100000012884603954_&yclid=1620693404391319098
#  domain_0 | www.natalie-tours.ru
#  domain_m | null
#  zone_0   | ru
# ...
#  url      | https://spb.oldi.ru/catalog/6535/dell/?utm_source=Yandex&utm_medium=cpc&utm_campaign=Oldi_ohvat_notebook_Spb_search.32071975.search&utm_term=%D0%9D%D0%BE%D1%83%D1%82%D0%B1%D1%83%D0%BA%20%D0%B4%D0%B5%D0%BB%D0%BB.11885718461&utm_content=3102229720.5172973542&utm_id=ic|32071975|3102229720|5172973542|11885718461||search|other&cm_id=32071975_3102229720_5172973542_11885718461__none_search_type1_no_desktop_other_2&_openstat=ZGlyZWN0LnlhbmRleC5ydTszMjA3MTk3NTs1MTcyOTczNTQyO3d3dy55YW5kZXgucnU6Z3VhcmFudGVl&yclid=1620683666132571818
#  domain_0 | spb.oldi.ru
#  domain_m | null
#  zone_0   | ru
#  zone_m   | not ru
# -RECORD 497---------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
#  url      | https://www.sportmaster.ru/product/10077014/?icid=catalog/muzhskaya_odezhda/sportivnye_kostyumy|listrec_DN|10077014
#  domain_0 | www.sportmaster.ru
#  domain_m | null
#  zone_0   | ru
#  zone_m   | not ru
# -RECORD 498---------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
#  url      | https://nova.rambler.ru/search?query=%D0%A1%D0%B0%D0%BD%D0%BA%D1%82-%D0%9F%D0%B5%D1%82%D0%B5%D1%80%D0%B1%D1%83%D1%80%D0%B3%20|%20%D0%96%D0%B5%D0%BD%D1%81%D0%BA%D0%B8%D0%B9%20%D0%BF%D0%BE%D1%80%D1%82%D0%B0%D0%BB%20+%20rutakedown.ru
#  domain_0 | nova.rambler.ru
#  domain_m | null
#  zone_0   | ru
#  zone_m   | not ru
# -RECORD 499---------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
#  url      | https://www.sportmaster.ru/product/10257385/?icid=catalog/roliki_skeytbordy_samokaty/zashchita_i_nakleyki/|sort_DN|10257385
#  domain_0 | www.sportmaster.ru
#  domain_m | null
#  zone_0   | ru
#  zone_m   | not ru
# only showing top 500 rows

# %%
page_views\
.filter(col("zone_0") == col("zone_m"))\
.select("url", "url_m", "domain", "zone_0", "zone", "zone_m")\
.show(50, vertical=True, truncate=False)
# Out:
# -RECORD 0--------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
#  url    | http
------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
#  url    | https://m.lenta.ru/photo/2018/03/31/egypt/
#  url_m  | m.lenta.ru
#  domain | m.lenta.ru
#  zone_0 | ru
#  zone   | ru
#  zone_m | ru
# -RECORD 23-------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
#  url    | https://evasmart.ru/?yclid=1620692173606622592
#  url_m  | evasmart.ru
#  domain | evasmart.ru
#  zone_0 | ru
#  zone   | ru
#  zone_m | ru
# -RECORD 24-------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
#  url    | http://evelinakhromtchenko.com/?cat=14
#  url_m  | evelinakhromtchenko.com
#  domain | evelinakhromtchenko.com
#  zone_0 | not ru
#  zone   | not ru
#  zone_m | not ru
# -RECORD 25-------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
#  url    | https://varlamov.ru/?.news=show
#  url_m  | varlamov.ru
#  domain | varlamov.ru
#  zone_0 | ru
#  zone   | ru
#  zone_m | ru
# -RECORD 26-------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
#  url    | https://ria.ru/lenta/person_Dmitrijj_Rogozin/
#  url_m  | ria.ru
#  domain | ria.ru
#  zone_0 | ru
#  zone   | ru
#  zone_m | ru
# -RECORD 27-------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
#  url    | http://dbsd.ru/contracts/sale-contract/
#  url_m  | dbsd.ru
#  domain | dbsd.ru
#  zone_0 | ru
#  zone   | ru
#  zone_m | ru
# -RECORD 28-------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
#  url    | http://9tv.co.il/
#  url_m  | 9tv.co.il
#  domain | 9tv.co.il
#  zone_0 | not ru
#  zone   | not ru
#  zone_m | not ru
# -RECORD 29-------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
#  url    | http://www.yaplakal.com/forum2/topic1761268.html
#  url_m  | www.yaplakal.com
#  domain | www.yaplakal.com
#  zone_0 | not ru
#  zone   | not ru
#  zone_m | not ru
# -RECORD 30-------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
#  url    | http://sims3pack.ru/sims-4/odezhda/odezhda-detskaya/page/21/
#  url_m  | sims3pack.ru
#  domain | sims3pack.ru
#  zone_0 | ru
#  zone   | ru
#  zone_m | ru
# -RECORD 31-------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
#  url    | https://life.ru/t/%D0%BD%D0%BE%D0%B2%D0%BE%D1%81%D1%82%D0%B8/1099102/akrobat_cirque_du_soleil_razbilsia_vo_vriemia_shou
#  url_m  | life.ru
#  domain | life.ru
#  zone_0 | ru
# ...
#  zone_0 | ru
#  zone   | ru
#  zone_m | ru
# -RECORD 40-------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
#  url    | https://nova.rambler.ru/search?utm_source=head&utm_campaign=self_promo&utm_medium=button&utm_content=search&_openstat=UmFtYmxlcl9NYWluOzs7&query=monstrum%20%D1%8E%D1%82%D1%83%D0%B1
#  url_m  | nova.rambler.ru
#  domain | nova.rambler.ru
#  zone_0 | ru
#  zone   | ru
#  zone_m | ru
# -RECORD 41-------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
#  url    | https://bmpd.livejournal.com/3143437.html?page=2
#  url_m  | bmpd.livejournal.com
#  domain | bmpd.livejournal.com
#  zone_0 | not ru
#  zone   | not ru
#  zone_m | not ru
# -RECORD 42-------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
#  url    | https://varlamov.ru/2848875.html
#  url_m  | varlamov.ru
#  domain | varlamov.ru
#  zone_0 | ru
#  zone   | ru
#  zone_m | ru
# -RECORD 43-------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
#  url    | https://b-picture.livejournal.com/
#  url_m  | b-picture.livejournal.com
#  domain | b-picture.livejournal.com
#  zone_0 | not ru
#  zone   | not ru
#  zone_m | not ru
# -RECORD 44-------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
#  url    | https://www.russianfood.org/recepty/ovoshhi_griby_i_jajca/kak_prigotovit_marinovannye_griby_na_zimu/8-1-0-5583
#  url_m  | www.russianfood.org
#  domain | www.russianfood.org
#  zone_0 | not ru
#  zone   | not ru
#  zone_m | not ru
# -RECORD 45-------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
#  url    | https://www.svyaznoy.ru/catalog/phone/225/motorola/moto-x-style
#  url_m  | www.svyaznoy.ru
#  domain | www.svyaznoy.ru
#  zone_0 | ru
#  zone   | ru
#  zone_m | ru
# -RECORD 46-------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
#  url    | https://superpuper.ru/ucp.php?i=pm&mode=compose&action=quotepost&sid=a4c20b1ff11a11fb236f353223cdbb02&p=4049798
#  url_m  | superpuper.ru
#  domain | superpuper.ru
#  zone_0 | ru
#  zone   | ru
#  zone_m | ru
# -RECORD 47-------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
#  url    | http://minecraft-book.ru/skins/girl/572872/
#  url_m  | minecraft-book.ru
#  domain | minecraft-book.ru
#  zone_0 | ru
#  zone   | ru
#  zone_m | ru
# -RECORD 48-------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
#  url    | http://www.fedsfm.ru/answers
#  url_m  | www.fedsfm.ru
#  domain | www.fedsfm.ru
#  zone_0 | ru
#  zone   | ru
#  zone_m | ru
# -RECORD 49-------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
#  url    | https://www.rf-cheats.ru/forum/showthread.php?t=131265
#  url_m  | www.rf-cheats.ru
#  domain | www.rf-cheats.ru
#  zone_0 | ru
#  zone   | ru
#  zone_m | ru
# only showing top 50 rows

# %%
srt_ = 'https://www.pleer.ru/product_251365_Element_878D.html?frommarket=https%3A//market.yandex.ru/catalog/57707/list%3Ftext%3Delement+878d%26hid%3D4981541%26clid%3D545%26suggest%3D2%26glfilter%3D7893318%3A14440125%26rt%3D11%26was_redir%3D1%26rs%3DeJwzqlWS5uJJzUnNTc0rUbAwt0gROPboIbMSCweDALsGg1EcVwwXL8eqI6wCLBIMqrUaU_cCuWdPs&ymclid=225888382199394701800002'

urlparse(unquote(srt_.strip())).netloc.strip()
# Out:
# 'www.pleer.ru'

# %%
streaming.stop()
